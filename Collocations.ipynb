# %% [markdown]
# # Collocations

# %%
#load all libraries
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
import spacy
import string

# %%
#load tweets data
tweets = pd.read_csv('tweets.csv')

# %%
tweets.head(2)
# Out:
#                                      tweet Column2 Column3 Column4 Column5  \
# 0      i should really update my avi soon.     NaN     NaN     NaN     NaN
# 1  i just rather for the truth to come out     NaN     NaN     NaN     NaN
#
#   Column6                                     TEXT
# 0     NaN      i should really update my avi soon.
# 1     NaN  i just rather for the truth to come out

# %% [markdown]
# Extract only the reviews...

# %%
comments = tweets['TEXT']
comments.describe()
# Out:
# count                        999972
# unique                       902352
# top       #jackandjackdoingitright
# freq                           2584
# Name: TEXT, dtype: object

# %% [markdown]
# ## Preprocessing

# %%
#function to remove non-ascii characters
def _removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

# %%
comments = comments.astype('str')

# %%
#remove non-ascii characters
comments = comments.map(lambda x: _removeNonAscii(x))

# %%
#get stop words of all languages
STOPWORDS_DICT = {lang: set(nltk.corpus.stopwords.words(lang)) for lang in nltk.corpus.stopwords.fileids()}

# %%
#function to detect language based on # of stop words for particular language
def get_language(text):
    words = set(nltk.wordpunct_tokenize(text.lower()))
    lang = max(((lang, len(words & stopwords)) for lang, stopwords in STOPWORDS_DICT.items()), key = lambda x: x[1])[0]
    if lang == 'english':
        return True
    else:
        return False

# %%
#filter for only english comments
eng_comments=comments[comments.apply(get_language)]

# %%
eng_comments.head(10)
# Out:
# 0                   i should really update my avi soon.
# 1               i just rather for the truth to come out
# 2                          i'm shooting charles barkley
# 3                         @kaylieaichner you're perfect
# 6     first 30seconds and i hate it! i got a ear inf...
# 7     but do not sleep late often because i will mak...
# 8                people criticize chris bosh too much..
# 9     up your followers here real aktif asli bukan o...
# 13                  its amazing. go get doing it right!
# 14    we had foods together and i wish we were bette...
# Name: TEXT, dtype: object

# %%
#drop duplicates
eng_comments.drop_duplicates(inplace=True)
eng_comments.describe()
# Out:
# count                                                481780
# unique                                               481780
# top       i use to think i was such a good judge of char...
# freq                                                      1
# Name: TEXT, dtype: object

# %%
#load spacy
nlp = spacy.load('en', disable=['parser','ner'])

# %%
#function to clean and lemmatize comments
def clean_comments(text):
    #remove punctuations
    regex = re.compile('[' + re.escape(string.punctuation) + '\\r\\t\\n]')
    nopunct = regex.sub(" ", str(text))
    #use spacy to lemmatize comments
    doc = nlp(nopunct)
    lemma = [token.lemma_ for token in doc]
    return lemma

# %%
#apply function to clean and lemmatize comments
lemmatized = eng_comments.map(clean_comments)

# %%
#make sure to lowercase everything
lemmatized = lemmatized.map(lambda x: [word.lower() for word in x])

# %%
lemmatized.head()
# Out:
# 0       [i, should, really, update, -pron-, avi, soon]
# 1    [i, just, rather, for, the, truth, to, come, out]
# 2                       [i, m, shoot, charle, barkley]
# 3              [ , kaylieaichner, -pron-, re, perfect]
# 6    [first, 30second, and, i, hate, -pron-,  , i, ...
# Name: TEXT, dtype: object

# %%
#turn all comments' tokens into one single list
unlist_comments = [item for items in lemmatized for item in items]

# %%
l=len(unlist_comments)
l
# Out:
# 5679407

# %% [markdown]
# ## Initialize NLTK's Bigrams Finder

# %%
bigrams = nltk.collocations.BigramAssocMeasures()

# %%
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(unlist_comments)

# %% [markdown]
# ## 1. Counting Frequencies of Adjacent Words
# - Main idea: simply order by frequency
# - Issues: too sensitive to very frequent pairs and pronouns/articles/prepositions come up often
# - Solution: filter for certain types of word pos

# %%
bigram_freq = bigramFinder.ngram_fd.items()

# %%
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)

# %%
bigramFreqTable.head(100).reset_index(drop=True)
# Out:
#               bigram   freq
# 0             (i, m)  39307
# 1       (-pron-, be)  31231
# 2           (don, t)  24904
# 3        (-pron-,  )  24219
# 4        (-pron-, s)  24111
# 5             ( , i)  18766
# 6        ( , -pron-)  17031
# 7       (be, -pron-)  13806
# 8            (i, be)  12936
# 9       (-pron-, re)  12282
# 10      (if, -pron-)  11902
# 11      (to, -pron-)  11746
# 12          (can, t)  11338
# 13          (go, to)  11129
# 14          (i, can)  10751
# 15  (-pron-, -pron-)  10444
# 16      (of, -pron-)  10410
# 17         (in, the)  10410
# 18           (be, a)  10310
# 19     (and, -pron-)  10087
# 20      (do, -pron-)   9852
# 21         (that, s)   9716
# 22          (i, don)   9609
# 23    (with, -pron-)   9376
# 24    (love, -pron-)   9122
# 25         (i, have)   9079
# 26          (to, be)   9079
# 27      (in, -pron-)   9033
# 28       (-pron-, i)   8981
# 29     (for, -pron-)   8966
# ..               ...    ...
# 70           (  , i)   4683
# 71          (ain, t)   4679
# 72         (i, know)   4676
# 73    (that, -pron-)   4556
# 74         (to, get)   4506
# 75       (-pron-, a)   4443
# 76      (-pron-, so)   4414
# 77     (-pron-, don)   4398
# 78     (see, -pron-)   4385
# 79    (-pron-, life)   4374
# 80        (so, much)   4330
# 81    (what, -pron-)   4303
# 82   (think, -pron-)   4194
# 83          (lol,  )   4190
# 84    (-pron-, know)   4118
# 85    (know, -pron-)   4110
# 86   (about, -pron-)   4102
# 87          (ne, to)   4057
# 88           (  ,  )   3986
# 89      (  , -pron-)   3921
# 90         (try, to)   3917
# 91         (that, i)   3894
# 92        (this, be)   3880
# 93      (right, now)   3867
# 94      (-pron-,   )   3847
# 95       (the, good)   3830
# 96    (-pron-, just)   3805
# 97         (i, hate)   3796
# 98    (have, -pron-)   3697
# 99          (y, all)   3686
#
# [100 rows x 2 columns]

# %%
bigramFreqTable[:10]
# Out:
#             bigram   freq
# 16          (i, m)  39307
# 86    (-pron-, be)  31231
# 136       (don, t)  24904
# 31     (-pron-,  )  24219
# 734    (-pron-, s)  24111
# 32          ( , i)  18766
# 300    ( , -pron-)  17031
# 99    (be, -pron-)  13806
# 1636       (i, be)  12936
# 23    (-pron-, re)  12282

# %%
#get english stopwordsor ' ' in ngram 
en_stopwords = set(stopwords.words('english'))

# %%
#function to filter for ADJ/NN bigrams
def rightTypes(ngram):
    if '-pron-' in ngram or '' in ngram or ' ' in ngram or 't' in ngram or 'ta' in ngram or '  ' in ngram:
        return False
    for word in ngram:
        if word in en_stopwords:
            return False
    acceptable_types = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS', 'VB', 'VBD','VBG','VBN','VBP','VBZ','RB','RBR', 'RBS','PRP$')
    second_type = ('NN', 'NNS', 'NNP', 'NNPS','VB', 'VBD','VBG','VBN','VBP','VBZ','RB','RBR', 'RBS','PRP$')
    tags = nltk.pos_tag(ngram) 
    if tags[0][1] in acceptable_types and tags[1][1] in second_type:
        return True
    else:
        return False

# %%
#filter bigrams
filtered_bi = bigramFreqTable[bigramFreqTable.bigram.map(lambda x: rightTypes(x))]

# %%
filtered_bi[:100]
# Out:
#                    bigram  freq
# 8224     (please, follow)  1536
# 2575       (fall, asleep)  1062
# 2696           (go, back)  1030
# 859          (come, back)   864
# 88         (good, friend)   831
# 253     (happy, birthday)   763
# 11959        (even, know)   752
# 12465         (wanna, go)   746
# 15482       (good, thing)   692
# 2205       (really, want)   635
# 393        (free, agency)   578
# 2010        (last, night)   524
# 126         (first, time)   523
# 5572     (lgg3ph, simply)   488
# 18230       (canada, day)   484
# 11843         (get, back)   482
# 13967        (never, get)   452
# 7517      (luke, hemming)   441
# 18394           (love, u)   439
# 20522       (late, night)   431
# 75              (go, get)   428
# 1671         (teen, wolf)   425
# 10366     (someone, else)   418
# 12711       (never, know)   417
# 6510      (good, morning)   399
# 1085      (look, forward)   391
# 3735         (long, time)   379
# 3142          (good, day)   370
# 8656        (good, night)   369
# 8734       (high, school)   358
# ...                   ...   ...
# 15655      (follow, back)   234
# 2896         (text, back)   231
# 1311      (people, think)   231
# 4185         (many, time)   229
# 26180    (everyone, else)   226
# 7345         (take, care)   224
# 12468    (say, something)   222
# 24690        (still, get)   220
# 33655  (jccaylen, please)   219
# 2028      (july, already)   218
# 9862      (really, wanna)   216
# 27504     (happy, canada)   209
# 16167        (real, life)   205
# 3174        (ne, someone)   203
# 29440        (wait, till)   203
# 38391       (wanna, know)   199
# 38590       (wide, awake)   197
# 20036       (thing, ever)   196
# 2614         (taco, bell)   196
# 30978    (work, tomorrow)   195
# 3216       (good, enough)   194
# 3479          (ever, get)   193
# 5313         (great, day)   193
# 77150    (please, please)   192
# 11593     (already, july)   192
# 20855      (really, love)   191
# 510        (finally, get)   190
# 6659        (little, bit)   188
# 35080       (really, get)   186
# 13568     (want, someone)   186
#
# [100 rows x 2 columns]

# %%
len(filtered_bi)
top100=filtered_bi[:100]
top100.bigram.values
# Out:
# array([('please', 'follow'), ('fall', 'asleep'), ('go', 'back'),
#        ('come', 'back'), ('good', 'friend'), ('happy', 'birthday'),
#        ('even', 'know'), ('wanna', 'go'), ('good', 'thing'),
#        ('really', 'want'), ('free', 'agency'), ('last', 'night'),
#        ('first', 'time'), ('lgg3ph', 'simply'), ('canada', 'day'),
#        ('get', 'back'), ('never', 'get'), ('luke', 'hemming'),
#        ('love', 'u'), ('late', 'night'), ('go', 'get'), ('teen', 'wolf'),
#        ('someone', 'else'), ('never', 'know'), ('good', 'morning'),
#        ('look', 'forward'), ('long', 'time'), ('good', 'day'),
#        ('good', 'night'), ('high', 'school'), ('ice', 'cream'),
#        ('last', 'time'), ('u', 'get'), ('come', 'home'), ('go', 'buy'),
#        ('new', 'song'), ('go', 'home'), ('holy', 'shit'), ('let', 'go'),
#        ('thank', 'god'), ('world', 'cup'), ('new', 'month'),
#        ('get', 'home'), ('many', 'people'), ('good', 'time'), ('na', 'go'),
#        ('always', 'get'), ('na', 'get'), ('next', 'time'),
#        ('wanna', 'see'), ('wanna', 'get'), ('make', 'sense'),
#        ('oh', 'well'), ('last', 'year'), ('anyone', 'else'),
#        ('year', 'ago'), ('talk', 'shit'), ('next', 'week'),
#        ('good', 'luck'), ('u', 'know'), ('already', 'know'),
#        ('next', 'year'), ('never', 'go'), ('ever', 'see'),
#        ('never', 'see'), ('wanna', 'talk'), ('   ', 'lol'),
#        ('social', 'medium'), ('people', 'say'), ('bad', 'thing'),
#        ('follow', 'back'), ('text', 'back'), ('people', 'think'),
#        ('many', 'time'), ('everyone', 'else'), ('take', 'care'),
#        ('say', 'something'), ('still', 'get'), ('jccaylen', 'please'),
#        ('july', 'already'), ('really', 'wanna'), ('happy', 'canada'),
#        ('real', 'life'), ('ne', 'someone'), ('wait', 'till'),
#        ('wanna', 'know'), ('wide', 'awake'), ('thing', 'ever'),
#        ('taco', 'bell'), ('work', 'tomorrow'), ('good', 'enough'),
#        ('ever', 'get'), ('great', 'day'), ('please', 'please'),
#        ('already', 'july'), ('really', 'love'), ('finally', 'get'),
#        ('little', 'bit'), ('really', 'get'), ('want', 'someone')], dtype=object)

# %%
freq_bi = filtered_bi[:100].bigram.values
freq_bi[1][0]
# Out:
# 'fall'

# %% [markdown]
# ## 2. PMI

# %%
bigramFinder.apply_freq_filter(100)

# %%
bigramPMITable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)

# %%
bigramPMITable[:100]
# Out:
#                    bigram        PMI
# 0        (peanut, butter)  14.586649
# 1          (hobby, lobby)  14.145231
# 2            (taco, bell)  13.804351
# 3            (nash, nash)  12.980102
# 4     (michael, clifford)  12.823400
# 5            (teen, wolf)  12.764447
# 6            (ice, cream)  12.699349
# 7      (tornado, warning)  12.631726
# 8        (social, medium)  12.503249
# 9       (social, network)  12.334934
# 10       (lgg3ph, simply)  12.239246
# 11        (luke, hemming)  12.224218
# 12       (birth, control)  12.131996
# 13          (wide, awake)  11.837264
# 14  (difference, between)  11.265003
# 15         (free, agency)  11.238683
# 16             (my, gosh)  11.054887
# 17          (free, agent)  10.787170
# 18         (fall, asleep)  10.391306
# 19               (ha, ha)  10.294519
# 20      (awkward, moment)  10.242504
# 21            (nba, free)  10.013231
# 22               (oh, my)   9.940335
# 23            (new, york)   9.927008
# 24          (each, other)   9.863710
# 25              (my, god)   9.804484
# 26             (24, hour)   9.673336
# 27           (world, cup)   9.653709
# 28              (gon, na)   9.555839
# 29       (pay, attention)   9.544715
# ..                    ...        ...
# 70             (wake, up)   7.526579
# 71            (big, deal)   7.448728
# 72           (wait, till)   7.439428
# 73           (turn, into)   7.437101
# 74       (worried, about)   7.429668
# 75            (lay, down)   7.413190
# 76      (complain, about)   7.376719
# 77            (no, puedo)   7.375683
# 78              (or, nah)   7.342161
# 79            (hang, out)   7.280993
# 80       (follow, button)   7.255929
# 81          (figure, out)   7.254825
# 82        (someone, else)   7.252121
# 83           (right, now)   7.251396
# 84       (everyone, else)   7.246442
# 85           (more, than)   7.230173
# 86            (too, lazy)   7.228894
# 87              (5, hour)   7.210536
# 88              (3, hour)   7.201601
# 89          (video, game)   7.171196
# 90         (worry, about)   7.163153
# 91           (good, luck)   7.161395
# 92             (yell, at)   7.137833
# 93          (make, sense)   7.124809
# 94         (obsess, with)   7.107739
# 95         (first, place)   7.106054
# 96            (hurry, up)   7.097952
# 97            (sit, here)   7.082666
# 98           (no, longer)   7.062686
# 99        (these, niggas)   7.061498
#
# [100 rows x 2 columns]

# %%
pmi_bi = bigramPMITable[:100].bigram.values
pmi_bi
# Out:
# array([('peanut', 'butter'), ('hobby', 'lobby'), ('taco', 'bell'),
#        ('nash', 'nash'), ('michael', 'clifford'), ('teen', 'wolf'),
#        ('ice', 'cream'), ('tornado', 'warning'), ('social', 'medium'),
#        ('social', 'network'), ('lgg3ph', 'simply'), ('luke', 'hemming'),
#        ('birth', 'control'), ('wide', 'awake'), ('difference', 'between'),
#        ('free', 'agency'), ('my', 'gosh'), ('free', 'agent'),
#        ('fall', 'asleep'), ('ha', 'ha'), ('awkward', 'moment'),
#        ('nba', 'free'), ('oh', 'my'), ('new', 'york'), ('each', 'other'),
#        ('my', 'god'), ('24', 'hour'), ('world', 'cup'), ('gon', 'na'),
#        ('pay', 'attention'), ('july', '1st'), ('simply', 'because'),
#        ('luke5sos', 'luke'), ('calm', 'down'), ('scary', 'movie'),
#        ('look', 'forward'), ('high', 'school'), ('middle', 'school'),
#        ('little', 'bit'), ('god', 'bless'), ('d', 'rather'),
#        ('real', 'quick'), ('o', 'o'), ('every', 'single'), ('year', 'ago'),
#        ('happy', 'birthday'), ('pretty', 'sure'), ('an', 'idiot'),
#        ('anyone', 'else'), ('canada', 'day'), ('hour', 'ago'),
#        ('an', 'asshole'), ('happy', 'canada'), ('hemming', 'from'),
#        ('far', 'away'), ('5', 'minute'), ('at', 'least'), ('walk', 'away'),
#        ('lgg3ph', 'because'), ('tv', 'show'), ('less', 'than'),
#        ('year', 'old'), ('shout', 'out'), ('week', 'ago'),
#        ('month', 'ago'), ('slow', 'down'), ('holy', 'shit'),
#        ('these', 'hoe'), ('next', 'week'), ('late', 'night'),
#        ('wake', 'up'), ('big', 'deal'), ('wait', 'till'), ('turn', 'into'),
#        ('worried', 'about'), ('lay', 'down'), ('complain', 'about'),
#        ('no', 'puedo'), ('or', 'nah'), ('hang', 'out'),
#        ('follow', 'button'), ('figure', 'out'), ('someone', 'else'),
#        ('right', 'now'), ('everyone', 'else'), ('more', 'than'),
#        ('too', 'lazy'), ('5', 'hour'), ('3', 'hour'), ('video', 'game'),
#        ('worry', 'about'), ('good', 'luck'), ('yell', 'at'),
#        ('make', 'sense'), ('obsess', 'with'), ('first', 'place'),
#        ('hurry', 'up'), ('sit', 'here'), ('no', 'longer'),
#        ('these', 'niggas')], dtype=object)

# %% [markdown]
# ## 3. Chi-Square

# %%
bigramChiTable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.chi_sq)), columns=['bigram','chi-sq']).sort_values(by='chi-sq', ascending=False)

# %%
bigramChiTable = bigramChiTable[bigramChiTable.bigram.map(lambda x: rightTypes(x))]

# %%
bigramChiTable.head(100)
# Out:
#                      bigram        chi-sq
# 1            (hobby, lobby)  3.080174e+06
# 2              (teen, wolf)  2.956892e+06
# 3              (taco, bell)  2.803896e+06
# 4          (peanut, butter)  2.681851e+06
# 5              (ice, cream)  2.374153e+06
# 6          (lgg3ph, simply)  2.359048e+06
# 8           (luke, hemming)  2.109776e+06
# 9            (fall, asleep)  1.425335e+06
# 10           (free, agency)  1.396259e+06
# 11         (social, medium)  1.393127e+06
# 12             (nash, nash)  9.532758e+05
# 15      (michael, clifford)  7.826963e+05
# 16            (wide, awake)  7.206095e+05
# 18       (tornado, warning)  6.345154e+05
# 19         (birth, control)  6.282034e+05
# 20        (social, network)  5.939869e+05
# 29            (free, agent)  3.107939e+05
# 35             (world, cup)  2.524857e+05
# 37        (happy, birthday)  2.303648e+05
# 38        (awkward, moment)  2.032558e+05
# 40         (please, follow)  1.947992e+05
# 44          (look, forward)  1.685436e+05
# 48           (high, school)  1.533216e+05
# 49                 (ha, ha)  1.429821e+05
# 53              (new, york)  1.371175e+05
# 56            (canada, day)  1.274754e+05
# 71         (luke5sos, luke)  9.051490e+04
# 77         (pay, attention)  8.271014e+04
# 78              (year, ago)  8.132890e+04
# 79            (late, night)  7.994218e+04
# ..                      ...           ...
# 343           (video, game)  1.564747e+04
# 345            (new, album)  1.560903e+04
# 358             (watch, tv)  1.443807e+04
# 359          (many, people)  1.438835e+04
# 364        (summer, school)  1.416526e+04
# 367             (wanna, go)  1.393088e+04
# 374            (last, time)  1.347502e+04
# 375            (last, week)  1.345439e+04
# 381           (good, thing)  1.325721e+04
# 387        (please, justin)  1.284220e+04
# 396            (next, time)  1.261357e+04
# 400        (favorite, song)  1.252105e+04
# 406           (never, fail)  1.227853e+04
# 416             (god, damn)  1.195136e+04
# 423                  (r, u)  1.179072e+04
# 427            (hell, yeah)  1.168385e+04
# 437               (yo, ass)  1.140311e+04
# 442  (justinbieber, follow)  1.121022e+04
# 470                  (u, r)  1.042578e+04
# 475          (really, want)  1.031633e+04
# 487             (dumb, ass)  1.008060e+04
# 503             (good, app)  9.625340e+03
# 504          (whole, world)  9.621424e+03
# 512          (still, awake)  9.342422e+03
# 515               (say, hi)  9.190976e+03
# 516            (take, care)  9.188285e+03
# 537            (head, hurt)  8.686943e+03
# 547            (text, back)  8.507807e+03
# 550             (go, ahead)  8.428264e+03
# 551     (never, understand)  8.375375e+03
#
# [100 rows x 2 columns]

# %%
chi_bi = bigramChiTable[:100].bigram.values
chi_bi
# Out:
# array([('hobby', 'lobby'), ('teen', 'wolf'), ('taco', 'bell'),
#        ('peanut', 'butter'), ('ice', 'cream'), ('lgg3ph', 'simply'),
#        ('luke', 'hemming'), ('fall', 'asleep'), ('free', 'agency'),
#        ('social', 'medium'), ('nash', 'nash'), ('michael', 'clifford'),
#        ('wide', 'awake'), ('tornado', 'warning'), ('birth', 'control'),
#        ('social', 'network'), ('free', 'agent'), ('world', 'cup'),
#        ('happy', 'birthday'), ('awkward', 'moment'), ('please', 'follow'),
#        ('look', 'forward'), ('high', 'school'), ('ha', 'ha'),
#        ('new', 'york'), ('canada', 'day'), ('luke5sos', 'luke'),
#        ('pay', 'attention'), ('year', 'ago'), ('late', 'night'),
#        ('anyone', 'else'), ('little', 'bit'), ('holy', 'shit'),
#        ('scary', 'movie'), ('someone', 'else'), ('last', 'night'),
#        ('god', 'bless'), ('real', 'quick'), ('happy', 'canada'),
#        ('next', 'week'), ('come', 'back'), ('make', 'sense'),
#        ('middle', 'school'), ('good', 'luck'), ('new', 'month'),
#        ('far', 'away'), ('wait', 'till'), ('new', 'song'),
#        ('everyone', 'else'), ('good', 'friend'), ('first', 'time'),
#        ('next', 'year'), ('tv', 'show'), ('july', 'already'),
#        ('last', 'year'), ('thank', 'god'), ('come', 'home'),
#        ('first', 'place'), ('jccaylen', 'please'), ('week', 'ago'),
#        ('big', 'deal'), ('month', 'ago'), ('white', 'girl'),
#        ('go', 'back'), ('already', 'july'), ('even', 'know'),
#        ('long', 'time'), ('oh', 'well'), ('good', 'morning'),
#        ('follow', 'button'), ('video', 'game'), ('new', 'album'),
#        ('watch', 'tv'), ('many', 'people'), ('summer', 'school'),
#        ('wanna', 'go'), ('last', 'time'), ('last', 'week'),
#        ('good', 'thing'), ('please', 'justin'), ('next', 'time'),
#        ('favorite', 'song'), ('never', 'fail'), ('god', 'damn'),
#        ('r', 'u'), ('hell', 'yeah'), ('yo', 'ass'),
#        ('justinbieber', 'follow'), ('u', 'r'), ('really', 'want'),
#        ('dumb', 'ass'), ('good', 'app'), ('whole', 'world'),
#        ('still', 'awake'), ('say', 'hi'), ('take', 'care'),
#        ('head', 'hurt'), ('text', 'back'), ('go', 'ahead'),
#        ('never', 'understand')], dtype=object)

# %% [markdown]
# ## Bigram Comparison

# %%
bigramsCompare = pd.DataFrame([freq_bi, pmi_bi, chi_bi]).T

# %%
bigramsCompare.columns = ['Frequency With Filter', 'PMI',  'Chi-Sq Test']

# %%
bigramsCompare
# Out:
#    Frequency With Filter                    PMI             Chi-Sq Test
# 0       (please, follow)       (peanut, butter)          (hobby, lobby)
# 1         (fall, asleep)         (hobby, lobby)            (teen, wolf)
# 2             (go, back)           (taco, bell)            (taco, bell)
# 3           (come, back)           (nash, nash)        (peanut, butter)
# 4         (good, friend)    (michael, clifford)            (ice, cream)
# 5      (happy, birthday)           (teen, wolf)        (lgg3ph, simply)
# 6           (even, know)           (ice, cream)         (luke, hemming)
# 7            (wanna, go)     (tornado, warning)          (fall, asleep)
# 8          (good, thing)       (social, medium)          (free, agency)
# 9         (really, want)      (social, network)        (social, medium)
# 10        (free, agency)       (lgg3ph, simply)            (nash, nash)
# 11         (last, night)        (luke, hemming)     (michael, clifford)
# 12         (first, time)       (birth, control)           (wide, awake)
# 13      (lgg3ph, simply)          (wide, awake)      (tornado, warning)
# 14         (canada, day)  (difference, between)        (birth, control)
# 15           (get, back)         (free, agency)       (social, network)
# 16          (never, get)             (my, gosh)           (free, agent)
# 17       (luke, hemming)          (free, agent)            (world, cup)
# 18             (love, u)         (fall, asleep)       (happy, birthday)
# 19         (late, night)               (ha, ha)       (awkward, moment)
# 20             (go, get)      (awkward, moment)        (please, follow)
# 21          (teen, wolf)            (nba, free)         (look, forward)
# 22       (someone, else)               (oh, my)          (high, school)
# 23         (never, know)            (new, york)                (ha, ha)
# 24       (good, morning)          (each, other)             (new, york)
# 25       (look, forward)              (my, god)           (canada, day)
# 26          (long, time)             (24, hour)        (luke5sos, luke)
# 27           (good, day)           (world, cup)        (pay, attention)
# 28         (good, night)              (gon, na)             (year, ago)
# 29        (high, school)       (pay, attention)           (late, night)
# ..                   ...                    ...                     ...
# 70        (follow, back)             (wake, up)           (video, game)
# 71          (text, back)            (big, deal)            (new, album)
# 72       (people, think)           (wait, till)             (watch, tv)
# 73          (many, time)           (turn, into)          (many, people)
# 74      (everyone, else)       (worried, about)        (summer, school)
# 75          (take, care)            (lay, down)             (wanna, go)
# 76      (say, something)      (complain, about)            (last, time)
# 77          (still, get)            (no, puedo)            (last, week)
# 78    (jccaylen, please)              (or, nah)           (good, thing)
# 79       (july, already)            (hang, out)        (please, justin)
# 80       (really, wanna)       (follow, button)            (next, time)
# 81       (happy, canada)          (figure, out)        (favorite, song)
# 82          (real, life)        (someone, else)           (never, fail)
# 83         (ne, someone)           (right, now)             (god, damn)
# 84          (wait, till)       (everyone, else)                  (r, u)
# 85         (wanna, know)           (more, than)            (hell, yeah)
# 86         (wide, awake)            (too, lazy)               (yo, ass)
# 87         (thing, ever)              (5, hour)  (justinbieber, follow)
# 88          (taco, bell)              (3, hour)                  (u, r)
# 89      (work, tomorrow)          (video, game)          (really, want)
# 90        (good, enough)         (worry, about)             (dumb, ass)
# 91           (ever, get)           (good, luck)             (good, app)
# 92          (great, day)             (yell, at)          (whole, world)
# 93      (please, please)          (make, sense)          (still, awake)
# 94       (already, july)         (obsess, with)               (say, hi)
# 95        (really, love)         (first, place)            (take, care)
# 96        (finally, get)            (hurry, up)            (head, hurt)
# 97         (little, bit)            (sit, here)            (text, back)
# 98         (really, get)           (no, longer)             (go, ahead)
# 99       (want, someone)        (these, niggas)     (never, understand)
#
# [100 rows x 3 columns]

# %%
bigramsCompare.to_excel("C:/data/690/zhaohui_690_assignment1.xlsx")
